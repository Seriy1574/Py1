# %% [markdown]
# # Предсказание цен на недвижимость

# %% [markdown]
# ### Импорт библиотек

# %%
import numpy as np
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import r2_score as r2, mean_absolute_error as mae, mean_squared_error as mse
from sklearn.model_selection import KFold, GridSearchCV

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
def evaluate_preds(true_values, pred_values):
    print("R2:\t" + str(round(r2(true_values, pred_values), 3)) + "\n" +
          "MAE:\t" + str(round(mae(true_values, pred_values), 3)) + "\n" +
          "MSE:\t" + str(round(mse(true_values, pred_values), 3)))
    
    plt.figure(figsize=(10,10))
    
    sns.scatterplot(x=pred_values, y=true_values)
    
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('True vs Predicted values')
    plt.show()

# %% [markdown]
# #### Описание датасета
#
# Id - идентификационный номер квартиры
# DistrictId - идентификационный номер района
# Rooms - количество комнат
# Square - площадь
# LifeSquare - жилая площадь
# KitchenSquare - площадь кухни
# Floor - этаж
# HouseFloor - количество этажей в доме
# HouseYear - год постройки дома
# Ecology_1, Ecology_2, Ecology_3 - экологические показатели местности
# Social_1, Social_2, Social_3 - социальные показатели местности
# Healthcare_1, Helthcare_2 - показатели местности, связанные с охраной здоровья
# Shops_1, Shops_2 - показатели, связанные с наличием магазинов, торговых центров
# Price - цена квартиры

# %% [markdown]
# #### указание пути к файлам

# %%
TEST = 'test.csv'
TRAIN = 'train.csv'
TEST_PREP = 'preptest.csv'
TRAIN_PREP = 'preptrain.csv'

# %% [markdown]
# ##### создание датафрейма для обработки

# %%
df = pd.read_csv(TRAIN)

# %%
df_test = pd.read_csv(TEST)

# %%
df.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644

# %%
df_test.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    725          58    2.0  49.882643   33.432782            6.0      6
# 1  15856          74    2.0  69.263183         NaN            1.0      6
# 2   5480         190    1.0  13.597819   15.948246           12.0      2
# 3  15664          47    2.0  73.046609   51.940842            9.0     22
# 4  14275          27    1.0  47.527111   43.387569            1.0     17
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        14.0       1972   0.310199         B         B        11      2748
# 1         1.0       1977   0.075779         B         B         6      1437
# 2         5.0       1909   0.000000         B         B        30      7538
# 3        22.0       2007   0.101872         B         B        23      4583
# 4        17.0       2017   0.072158         B         B         2       629
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0         1           NaN            0        0       B
# 1         3           NaN            0        2       B
# 2        87        4702.0            5        5       B
# 3         3           NaN            3        3       B
# 4         1           NaN            0        0       A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#            Social_1      Social_2      Social_3  Healthcare_1   Helthcare_2  \
# count  10000.000000  10000.000000  10000.000000   5202.000000  10000.000000
# mean      24.687000   5352.157400      8.039200   1142.904460      1.319500
# std       17.532614   4006.799803     23.831875   1021.517264      1.493601
# min        0.000000    168.000000      0.000000      0.000000      0.000000
# 25%        6.000000   1564.000000      0.000000    350.000000      0.000000
# 50%       25.000000   5285.000000      2.000000    900.000000      1.000000
# 75%       36.000000   7227.000000      5.000000   1548.000000      2.000000
# max       74.000000  19083.000000    141.000000   4849.000000      6.000000
#
#             Shops_1          Price
# count  10000.000000   10000.000000
# mean       4.231300  214138.857399
# std        4.806341   92872.293865
# min        0.000000   59174.778028
# 25%        1.000000  153872.633942
# 50%        3.000000  192269.644879
# 75%        6.000000  249135.462171
# max       23.000000  633233.466570

# %% [markdown]
# ### Обработка исходных данных

# %% [markdown]
# #### Исключаем признак ID

# %%
df = df[df.columns[1:]]

# %% [markdown]
# #### Поиск пустых значений

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(8), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# #### замена пустых и экстремальных признаков Healthcare_1 на медианное значение

# %%
df.loc[df['Healthcare_1'].isnull(),'Healthcare_1'] = df['Healthcare_1'].median()

# %%
df.loc[df['Rooms'] == 0, 'Rooms'] = df['Rooms'].mode()[0] ## спорная замена

# %%
df.loc[df['Rooms'] > 5, 'Rooms'] = df['Rooms'].mode()[0]  ## спорная замена

# %%
df.loc[df['KitchenSquare'] > 30, 'KitchenSquare'] = df['KitchenSquare'].mode()[0]

# %%
df.loc[df['KitchenSquare'] > df['Square'],'Square'] = df['KitchenSquare'] + df['LifeSquare']

# %%
df.loc[df['HouseYear'] > 2019, 'HouseYear'] = df['HouseYear'].mode()[0]

# %%
df.loc[df['Floor'] > df['HouseFloor'],'HouseFloor'] = df['Floor']

# %%
df.loc[df['HouseFloor'] > 90, 'HouseFloor'] = df['Floor']

# %%
##df.drop('Healthcare_1', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     10000 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(8), object(3)
# memory usage: 1.4+ MB

# %%
df.loc[df['LifeSquare'].isnull()]
# Out:
#       DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7             74    2.0   80.312926         NaN            0.0     14
# 8              1    2.0   64.511437         NaN            1.0      9
# 21            27    2.0   64.711835         NaN            1.0     15
# 23            54    3.0  118.907612         NaN            0.0      2
# 25            74    2.0   82.667915         NaN            1.0     16
# ...          ...    ...         ...         ...            ...    ...
# 9985          27    1.0   38.968338         NaN            1.0     10
# 9986           1    2.0   64.994245         NaN            1.0      9
# 9987          23    2.0   55.620092         NaN            0.0      2
# 9994          23    2.0   64.864198         NaN            1.0     17
# 9997          27    1.0   47.939008         NaN            1.0     12
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 7           14.0       1977   0.075779         B         B         6
# 8           17.0       1977   0.007122         B         B         1
# 21          15.0       1977   0.211401         B         B         9
# 23           2.0       1977   0.006076         B         B        30
# 25          17.0       1977   0.075779         B         B         6
# ...          ...        ...        ...       ...       ...       ...
# 9985        10.0       1977   0.211401         B         B         9
# 9986        22.0       1977   0.007122         B         B         1
# 9987         4.0       1977   0.034656         B         B         0
# 9994        17.0       1977   0.075779         B         B         6
# 9997        16.0       2015   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 7         1437         3         900.0            0        2       B
# 8          264         0         900.0            0        1       B
# 21        1892         0         900.0            0        1       B
# 23        5285         0         645.0            6        6       B
# 25        1437         3         900.0            0        2       B
# ...        ...       ...           ...          ...      ...     ...
# 9985      1892         0         900.0            0        1       B
# 9986       264         0         900.0            0        1       B
# 9987       168         0         900.0            0        0       B
# 9994      1437         3         900.0            0        2       B
# 9997       629         1         900.0            0        0       A
#
#               Price
# 7     221244.156664
# 8     229102.795999
# 21    127200.026511
# 23    571069.052600
# 25    244145.827069
# ...             ...
# 9985   95529.569405
# 9986  200332.511658
# 9987  115797.553006
# 9994  171323.515653
# 9997  159143.805370
#
# [2113 rows x 19 columns]

# %%
df.describe()
# Out:
#          DistrictId         Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.888400     56.315775    37.199645       5.680700
# std       43.587592      0.811056     21.058732    86.241209       3.944452
# min        0.000000      1.000000      1.136859     0.370619       0.000000
# 25%       20.000000      1.000000     41.774881    22.769832       1.000000
# 50%       36.000000      2.000000     52.513310    32.781260       6.000000
# 75%       75.000000      2.000000     65.900625    45.128803       9.000000
# max      209.000000      5.000000    641.065193  7480.592129      30.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       8.526700     13.406100   1984.782100      0.118858     24.687000
# std        5.241148      5.883421     18.349177      0.119025     17.532614
# min        1.000000      1.000000   1910.000000      0.000000      0.000000
# 25%        4.000000      9.000000   1974.000000      0.017647      6.000000
# 50%        7.000000     14.000000   1977.000000      0.075424     25.000000
# 75%       12.000000     17.000000   2001.000000      0.195781     36.000000
# max       42.000000     48.000000   2019.000000      0.521867     74.000000
#
#            Social_2      Social_3  Healthcare_1   Helthcare_2       Shops_1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    5352.157400      8.039200   1026.358900      1.319500      4.231300
# std     4006.799803     23.831875    746.662828      1.493601      4.806341
# min      168.000000      0.000000      0.000000      0.000000      0.000000
# 25%     1564.000000      0.000000    830.000000      0.000000      1.000000
# 50%     5285.000000      2.000000    900.000000      1.000000      3.000000
# 75%     7227.000000      5.000000    990.000000      2.000000      6.000000
# max    19083.000000    141.000000   4849.000000      6.000000     23.000000
#
#                Price
# count   10000.000000
# mean   214138.857399
# std     92872.293865
# min     59174.778028
# 25%    153872.633942
# 50%    192269.644879
# 75%    249135.462171
# max    633233.466570

# %% [markdown]
# ##### вычисление отношения жилой прощади к нежилой у нормальных прощадей

# %%
df_norm = df[df['LifeSquare'].notnull() & (df['Square'] > df['LifeSquare'])]

# %%
df_norm['l/s'] = df_norm['Square']/ df_norm['LifeSquare']

# %%
df_norm
# Out:
#       DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0             35    2.0  47.981561   29.442751            6.0      7
# 1             41    3.0  65.683640   40.049543            8.0      7
# 2             53    2.0  44.947953   29.197612            0.0      8
# 3             58    2.0  53.352981   52.731512            9.0      8
# 4             99    1.0  39.649192   23.776169            7.0     11
# ...          ...    ...        ...         ...            ...    ...
# 9993          13    3.0  80.631333   48.899083           10.0     11
# 9995          32    2.0  50.401785   30.476203            5.0      6
# 9996          18    1.0  41.521546   20.539216            9.0     13
# 9998          75    2.0  43.602562   33.840147            8.0      1
# 9999         128    1.0  38.666645   21.157874            8.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 0            9.0       1969   0.089040         B         B        33
# 1            9.0       1978   0.000070         B         B        46
# 2           12.0       1968   0.049637         B         B        34
# 3           17.0       1977   0.437885         B         B        23
# 4           12.0       1976   0.012339         B         B        35
# ...          ...        ...        ...       ...       ...       ...
# 9993        14.0       1999   0.090799         B         B        74
# 9995         6.0       1968   0.135650         B         B        46
# 9996        13.0       2000   0.000000         B         B        30
# 9998         5.0       1961   0.307467         B         A        30
# 9999        17.0       1990   0.000000         B         B        27
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 0         7976         5         900.0            0       11       B
# 1        10309         1         240.0            1       16       B
# 2         7759         0         229.0            1        3       B
# 3         5735         3        1084.0            0        5       B
# 4         5776         1        2078.0            2        4       B
# ...        ...       ...           ...          ...      ...     ...
# 9993     19083         2         900.0            5       15       B
# 9995      7960         6         350.0            3       11       B
# 9996      5562         0         900.0            0        5       A
# 9998      5048         9         325.0            2        5       B
# 9999      4798         0          30.0            2        8       B
#
#               Price       l/s
# 0     184966.930730  1.629656
# 1     300009.450063  1.640060
# 2     220925.908524  1.539439
# 3     175616.227217  1.011786
# 4     150226.531644  1.667602
# ...             ...       ...
# 9993  350684.628560  1.648933
# 9995  196684.316040  1.653808
# 9996  189050.289571  2.021574
# 9998  181595.339808  1.288486
# 9999  218714.077615  1.827530
#
# [7405 rows x 20 columns]

# %%
df[df['Square'] <= df['LifeSquare']]
# Out:
#       DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 28            23    1.0   42.530043   43.967759            1.0      3
# 44            38    3.0  104.211396  106.340403            0.0     20
# 52             1    2.0   61.400054   65.224603            0.0     17
# 123           25    3.0   85.952306   89.803753            1.0      4
# 153           62    1.0   51.831473   53.491301            1.0      5
# ...          ...    ...         ...         ...            ...    ...
# 9884          30    2.0   59.015896   59.439082           12.0      5
# 9889          23    2.0   51.440463   53.134243            1.0      3
# 9895          27    3.0  123.430072  125.806981            1.0      5
# 9902          73    1.0   44.098768   44.267551            1.0      7
# 9910          27    4.0  200.334539  201.627361           25.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 28           9.0       2014   0.034656         B         B         0
# 44          20.0       2017   0.060753         B         B        15
# 52          22.0       2016   0.007122         B         B         1
# 123          4.0       2017   0.069753         B         B        53
# 153          5.0       2015   0.072158         B         B         2
# ...          ...        ...        ...       ...       ...       ...
# 9884         5.0       2016   0.000078         B         B        22
# 9889        17.0       2017   0.005767         B         B         1
# 9895        10.0       2015   0.017647         B         B         2
# 9902        24.0       2014   0.042032         B         B        37
# 9910         2.0       2013   0.041116         B         B        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 28         168         0         900.0            0        0       B
# 44        2787         2         520.0            0        7       B
# 52         264         0         900.0            0        1       B
# 123      13670         4         900.0            1       11       B
# 153        629         1         900.0            0        0       A
# ...        ...       ...           ...          ...      ...     ...
# 9884      6398       141        1046.0            3       23       B
# 9889       388         0         900.0            0        0       B
# 9895       469         0         900.0            0        0       B
# 9902      6856        84        1940.0            2        5       B
# 9910     14892         4         900.0            1        4       B
#
#               Price
# 28     95338.198549
# 44    435462.048070
# 52    199215.452229
# 123   309688.592681
# 153   131797.472284
# ...             ...
# 9884  126281.142781
# 9889   88150.012510
# 9895  234194.837047
# 9902  381937.404161
# 9910  528560.506016
#
# [482 rows x 19 columns]

# %% [markdown]
# #### проверка где общая площадь меньше жилой

# %%
df[df['Square'] <= df['LifeSquare']]
# Out:
#       DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 28            23    1.0   42.530043   43.967759            1.0      3
# 44            38    3.0  104.211396  106.340403            0.0     20
# 52             1    2.0   61.400054   65.224603            0.0     17
# 123           25    3.0   85.952306   89.803753            1.0      4
# 153           62    1.0   51.831473   53.491301            1.0      5
# ...          ...    ...         ...         ...            ...    ...
# 9884          30    2.0   59.015896   59.439082           12.0      5
# 9889          23    2.0   51.440463   53.134243            1.0      3
# 9895          27    3.0  123.430072  125.806981            1.0      5
# 9902          73    1.0   44.098768   44.267551            1.0      7
# 9910          27    4.0  200.334539  201.627361           25.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 28           9.0       2014   0.034656         B         B         0
# 44          20.0       2017   0.060753         B         B        15
# 52          22.0       2016   0.007122         B         B         1
# 123          4.0       2017   0.069753         B         B        53
# 153          5.0       2015   0.072158         B         B         2
# ...          ...        ...        ...       ...       ...       ...
# 9884         5.0       2016   0.000078         B         B        22
# 9889        17.0       2017   0.005767         B         B         1
# 9895        10.0       2015   0.017647         B         B         2
# 9902        24.0       2014   0.042032         B         B        37
# 9910         2.0       2013   0.041116         B         B        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 28         168         0         900.0            0        0       B
# 44        2787         2         520.0            0        7       B
# 52         264         0         900.0            0        1       B
# 123      13670         4         900.0            1       11       B
# 153        629         1         900.0            0        0       A
# ...        ...       ...           ...          ...      ...     ...
# 9884      6398       141        1046.0            3       23       B
# 9889       388         0         900.0            0        0       B
# 9895       469         0         900.0            0        0       B
# 9902      6856        84        1940.0            2        5       B
# 9910     14892         4         900.0            1        4       B
#
#               Price
# 28     95338.198549
# 44    435462.048070
# 52    199215.452229
# 123   309688.592681
# 153   131797.472284
# ...             ...
# 9884  126281.142781
# 9889   88150.012510
# 9895  234194.837047
# 9902  381937.404161
# 9910  528560.506016
#
# [482 rows x 19 columns]

# %%
df_norm['l/s'].median()
# Out:
# 1.637744365907453

# %% [markdown]
# #### замена площадей.

# %%
df.loc[df['Square'] < df['LifeSquare'],'Square'] = df['LifeSquare'] + df['KitchenSquare']  ## df['Square'] / df_norm['l/s'].median()

# %%
df.loc[df['LifeSquare'].isnull(), 'LifeSquare'] = df['Square'] - df['KitchenSquare'] ##/ df_norm['l/s'].median()

# %%
df.loc[df['LifeSquare'] < df['KitchenSquare'],'KitchenSquare']  =  df['Square'] - df['LifeSquare']

# %%
df.loc[df['LifeSquare'] < df['KitchenSquare']]
# Out:
#       DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1800          27    1.0  37.805231    2.228592      35.576639      6
# 1972          62    1.0  41.735073   12.423180      29.311892      3
# 5232          23    1.0  55.282148   11.168019      44.114129      4
# 5653          31    1.0  80.606246   25.299592      55.306654      6
# 5786          27    2.0  43.956044   10.523868      33.432175     15
# 8556          27    1.0  32.712359   11.047605      21.664754      8
# 9317         161    1.0  50.808925   15.920343      34.888582      8
# 9602           6    2.0  63.591740    0.795539      62.796200     17
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1800         6.0       2015   0.017647         B         B         2
# 1972        15.0       2010   0.072158         B         B         2
# 5232         4.0       2013   0.014073         B         B         2
# 5653        40.0       2014   0.151346         B         A        32
# 5786        17.0       2006   0.075424         B         B        11
# 8556        25.0       2016   0.072158         B         B         2
# 9317         9.0       1910   0.014423         B         B        19
# 9602        17.0       2014   0.243205         B         B         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1800       469         0         900.0            0        0       B
# 1972       629         1         900.0            0        0       A
# 5232       475         0         900.0            0        0       B
# 5653      5889        10         830.0            4        1       B
# 5786      3097         0         900.0            0        0       B
# 8556       629         1         900.0            0        0       A
# 9317      3806         4         900.0            0        3       B
# 9602      1564         0         540.0            0        0       B
#
#               Price
# 1800  137402.092529
# 1972   80331.107871
# 5232  157140.848998
# 5653  460492.010947
# 5786  143688.076514
# 8556   94433.038958
# 9317  287954.720682
# 9602  174741.998061

# %%
df['KitchenSquare'].value_counts()
# Out:
# 1.000000     2496
# 8.000000     1306
# 5.000000     1169
# 10.000000    1074
# 6.000000     1038
# 9.000000      843
# 0.000000      697
# 7.000000      609
# 12.000000     249
# 11.000000     232
# 13.000000      66
# 14.000000      50
# 4.000000       39
# 15.000000      31
# 3.000000       22
# 16.000000      16
# 17.000000      12
# 20.000000      12
# 19.000000      10
# 18.000000       6
# 2.000000        4
# 22.000000       3
# 25.000000       2
# 30.000000       2
# 44.114129       1
# 33.432175       1
# 35.576639       1
# 27.000000       1
# 21.000000       1
# 29.311892       1
# 34.888582       1
# 23.000000       1
# 26.000000       1
# 62.796200       1
# 21.664754       1
# 55.306654       1
# Name: KitchenSquare, dtype: int64

# %%
df.describe()
# Out:
#          DistrictId         Rooms        Square    LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean      50.400800      1.888400     57.365584     41.805574       5.698809
# std       43.587592      0.811056     77.349457     77.822881       4.059762
# min        0.000000      1.000000      2.377248      0.370619       0.000000
# 25%       20.000000      1.000000     41.967568     25.502330       1.000000
# 50%       36.000000      2.000000     52.739475     37.051273       6.000000
# 75%       75.000000      2.000000     66.140590     49.831651       9.000000
# max      209.000000      5.000000   7481.592129   7480.592129      62.796200
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       8.526700     13.406100   1984.782100      0.118858     24.687000
# std        5.241148      5.883421     18.349177      0.119025     17.532614
# min        1.000000      1.000000   1910.000000      0.000000      0.000000
# 25%        4.000000      9.000000   1974.000000      0.017647      6.000000
# 50%        7.000000     14.000000   1977.000000      0.075424     25.000000
# 75%       12.000000     17.000000   2001.000000      0.195781     36.000000
# max       42.000000     48.000000   2019.000000      0.521867     74.000000
#
#            Social_2      Social_3  Healthcare_1   Helthcare_2       Shops_1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    5352.157400      8.039200   1026.358900      1.319500      4.231300
# std     4006.799803     23.831875    746.662828      1.493601      4.806341
# min      168.000000      0.000000      0.000000      0.000000      0.000000
# 25%     1564.000000      0.000000    830.000000      0.000000      1.000000
# 50%     5285.000000      2.000000    900.000000      1.000000      3.000000
# 75%     7227.000000      5.000000    990.000000      2.000000      6.000000
# max    19083.000000    141.000000   4849.000000      6.000000     23.000000
#
#                Price
# count   10000.000000
# mean   214138.857399
# std     92872.293865
# min     59174.778028
# 25%    153872.633942
# 50%    192269.644879
# 75%    249135.462171
# max    633233.466570

# %%
plt.figure(figsize = (16, 8))

df['Price'].hist(bins=60)
plt.ylabel('count')
plt.xlabel('Price')

plt.title('Price')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       10000 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     10000 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(8), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# ##### Приведение к бинарным признакам

# %%
df = pd.concat([df, pd.get_dummies(df[['Ecology_2', 'Ecology_3', 'Shops_2']])], axis=1)

# %%
df
# Out:
#       DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0             35    2.0  47.981561   29.442751            6.0      7
# 1             41    3.0  65.683640   40.049543            8.0      7
# 2             53    2.0  44.947953   29.197612            0.0      8
# 3             58    2.0  53.352981   52.731512            9.0      8
# 4             99    1.0  39.649192   23.776169            7.0     11
# ...          ...    ...        ...         ...            ...    ...
# 9995          32    2.0  50.401785   30.476203            5.0      6
# 9996          18    1.0  41.521546   20.539216            9.0     13
# 9997          27    1.0  47.939008   46.939008            1.0     12
# 9998          75    2.0  43.602562   33.840147            8.0      1
# 9999         128    1.0  38.666645   21.157874            8.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2  ... Helthcare_2  Shops_1  \
# 0            9.0       1969   0.089040         B  ...           0       11
# 1            9.0       1978   0.000070         B  ...           1       16
# 2           12.0       1968   0.049637         B  ...           1        3
# 3           17.0       1977   0.437885         B  ...           0        5
# 4           12.0       1976   0.012339         B  ...           2        4
# ...          ...        ...        ...       ...  ...         ...      ...
# 9995         6.0       1968   0.135650         B  ...           3       11
# 9996        13.0       2000   0.000000         B  ...           0        5
# 9997        16.0       2015   0.072158         B  ...           0        0
# 9998         5.0       1961   0.307467         B  ...           2        5
# 9999        17.0       1990   0.000000         B  ...           2        8
#
#       Shops_2          Price  Ecology_2_A  Ecology_2_B  Ecology_3_A  \
# 0           B  184966.930730            0            1            0
# 1           B  300009.450063            0            1            0
# 2           B  220925.908524            0            1            0
# 3           B  175616.227217            0            1            0
# 4           B  150226.531644            0            1            0
# ...       ...            ...          ...          ...          ...
# 9995        B  196684.316040            0            1            0
# 9996        A  189050.289571            0            1            0
# 9997        A  159143.805370            0            1            0
# 9998        B  181595.339808            0            1            1
# 9999        B  218714.077615            0            1            0
#
#      Ecology_3_B  Shops_2_A  Shops_2_B
# 0              1          0          1
# 1              1          0          1
# 2              1          0          1
# 3              1          0          1
# 4              1          0          1
# ...          ...        ...        ...
# 9995           1          0          1
# 9996           1          1          0
# 9997           1          1          0
# 9998           0          0          1
# 9999           1          0          1
#
# [10000 rows x 25 columns]

# %% [markdown]
# #### Отбор признаков

# %%
df.columns.tolist()
# Out:
# ['DistrictId',
#  'Rooms',
#  'Square',
#  'LifeSquare',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'HouseYear',
#  'Ecology_1',
#  'Ecology_2',
#  'Ecology_3',
#  'Social_1',
#  'Social_2',
#  'Social_3',
#  'Healthcare_1',
#  'Helthcare_2',
#  'Shops_1',
#  'Shops_2',
#  'Price',
#  'Ecology_2_A',
#  'Ecology_2_B',
#  'Ecology_3_A',
#  'Ecology_3_B',
#  'Shops_2_A',
#  'Shops_2_B']

# %%
feature_names = ['DistrictId',
 'Rooms',
 'Square',
 'KitchenSquare',
 'Floor',
 'HouseFloor',
 'HouseYear',
 'Ecology_1',
 'Social_1',
 'Social_3',
 'Healthcare_1,
 'Helthcare_2',
 'Shops_1',
 'Ecology_2_B',
 'Ecology_3_B',
 'Shops_2_B']
# Out:
#   File "<ipython-input-666-93acf2c7327a>", line 11
#     'Healthcare_1,
#                   ^
# SyntaxError: EOL while scanning string literal

# %%
target_name = 'Price'

# %%
df = df[feature_names + [target_name]]
df.head()
# Out:
#    DistrictId  Rooms     Square  KitchenSquare  Floor  HouseFloor  HouseYear  \
# 0          35    2.0  47.981561            6.0      7         9.0       1969
# 1          41    3.0  65.683640            8.0      7         9.0       1978
# 2          53    2.0  44.947953            0.0      8        12.0       1968
# 3          58    2.0  53.352981            9.0      8        17.0       1977
# 4          99    1.0  39.649192            7.0     11        12.0       1976
#
#    Ecology_1  Social_1  Social_3  Helthcare_2  Shops_1  Ecology_2_B  \
# 0   0.089040        33         5            0       11            1
# 1   0.000070        46         1            1       16            1
# 2   0.049637        34         0            1        3            1
# 3   0.437885        23         3            0        5            1
# 4   0.012339        35         1            2        4            1
#
#    Ecology_3_B  Shops_2_B          Price
# 0            1          1  184966.930730
# 1            1          1  300009.450063
# 2            1          1  220925.908524
# 3            1          1  175616.227217
# 4            1          1  150226.531644

# %% [markdown]
# #### Стандартизация признаков

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Social_1         10000 non-null int64
# Social_3         10000 non-null int64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Ecology_2_B      10000 non-null uint8
# Ecology_3_B      10000 non-null uint8
# Shops_2_B        10000 non-null uint8
# Price            10000 non-null float64
# dtypes: float64(6), int64(7), uint8(3)
# memory usage: 1.0 MB

# %%
feature_names_for_stand = df[feature_names].columns.tolist()
feature_names_for_stand
# Out:
# ['DistrictId',
#  'Rooms',
#  'Square',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'HouseYear',
#  'Ecology_1',
#  'Social_1',
#  'Social_3',
#  'Helthcare_2',
#  'Shops_1',
#  'Ecology_2_B',
#  'Ecology_3_B',
#  'Shops_2_B']

# %%
scaler = StandardScaler()
stand_features = scaler.fit_transform(df[feature_names_for_stand])

# %%
stand_features
# Out:
# array([[-0.35334758,  0.13760533, -0.39578028, ...,  0.09896975,
#          0.16815955,  0.29986373],
#        [-0.21568684,  1.37062805,  0.44486692, ...,  0.09896975,
#          0.16815955,  0.29986373],
#        [ 0.05963463,  0.13760533, -0.53984214, ...,  0.09896975,
#          0.16815955,  0.29986373],
#        ...,
#        [-0.53689523, -1.09541738, -0.39780109, ...,  0.09896975,
#          0.16815955, -3.33484814],
#        [ 0.56439067,  0.13760533, -0.60373291, ...,  0.09896975,
#         -5.94673325,  0.29986373],
#        [ 1.78039385, -1.09541738, -0.83813275, ...,  0.09896975,
#          0.16815955,  0.29986373]])

# %%
df[feature_names_for_stand] = pd.DataFrame(stand_features, columns=feature_names_for_stand)

# %%
df.head(10)
# Out:
#    DistrictId     Rooms    Square  KitchenSquare     Floor  HouseFloor  \
# 0   -0.353348  0.137605 -0.395780       0.080261 -0.291306   -0.748938
# 1   -0.215687  1.370628  0.444867       0.582737 -0.291306   -0.748938
# 2    0.059635  0.137605 -0.539842      -1.427167 -0.100498   -0.239006
# 3    0.174352  0.137605 -0.140699       0.833975 -0.100498    0.610883
# 4    1.115034 -1.095417 -0.791473       0.331499  0.471924   -0.239006
# 5    0.197295  1.370628  1.142989       1.587689 -0.672921    0.610883
# 6    2.376924  0.137605  0.282003       0.331499 -1.054535   -1.428849
# 7    0.541447  0.137605  1.139591      -1.427167  1.044346    0.100950
# 8   -1.133425  0.137605  0.389201      -1.175929  0.090309    0.610883
# 9   -0.628669 -1.095417 -0.467970       0.582737  0.853539    0.610883
#
#    HouseYear  Ecology_1  Social_1  Social_3  Helthcare_2   Shops_1  \
# 0  -0.860142  -0.250529  0.474169 -0.127533    -0.883480  1.408356
# 1  -0.369632  -0.998053  1.215681 -0.295384    -0.213923  2.448700
# 2  -0.914643  -0.581588  0.531208 -0.337347    -0.213923 -0.256195
# 3  -0.424133   2.680470 -0.096225 -0.211458    -0.883480  0.159943
# 4  -0.478634  -0.894969  0.588247 -0.295384     0.455633 -0.048126
# 5   1.428904   1.601602  0.588247 -0.169496    -0.883480  0.368011
# 6  -1.350651   2.870953 -0.267344  0.250131    -0.213923  0.159943
# 7  -0.424133  -0.361948 -1.065895 -0.211458    -0.883480 -0.464264
# 8  -0.424133  -0.938799 -1.351093 -0.337347    -0.883480 -0.672333
# 9   1.592407  -0.361948 -1.065895 -0.211458    -0.883480 -0.464264
#
#    Ecology_2_B  Ecology_3_B  Shops_2_B          Price
# 0      0.09897      0.16816   0.299864  184966.930730
# 1      0.09897      0.16816   0.299864  300009.450063
# 2      0.09897      0.16816   0.299864  220925.908524
# 3      0.09897      0.16816   0.299864  175616.227217
# 4      0.09897      0.16816   0.299864  150226.531644
# 5      0.09897      0.16816   0.299864  215898.447742
# 6      0.09897      0.16816   0.299864  296021.204377
# 7      0.09897      0.16816   0.299864  221244.156664
# 8      0.09897      0.16816   0.299864  229102.795999
# 9      0.09897      0.16816   0.299864   95380.220993

# %% [markdown]
# #### Матрица корреляций

# %%
plt.figure(figsize = (19,19))

sns.set(font_scale=1.1)
sns.heatmap(df.corr(), annot=True, linewidths=.5, cmap='GnBu')

plt.title('Correlation matrix  ')
plt.show()

# %% [markdown]
# #### Сохранение обработанного обучающего датасета в csv

# %%
df.to_csv(TEST_PREP, index=False, encoding='utf-8')

# %% [markdown]
# #### Разбиение на train и test

# %%
x = df[feature_names]
y = df[target_name]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, shuffle=True, random_state=42)

# %% [markdown]
# ## Построение базовых моделей и выбор лучшей

# %% [markdown]
# #### Линейная регрессия

# %%
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_preds = lr_model.predict(x_train)
evaluate_preds(y_train, y_train_preds)
# Out:
# R2:	0.524
# MAE:	43875.313
# MSE:	4077560486.512

# %%
y_test_preds = lr_model.predict(x_test)
evaluate_preds(y_test, y_test_preds)
# Out:
# R2:	0.473
# MAE:	45120.517
# MSE:	4645218323.967

# %%
plt.barh(x_train.columns, lr_model.coef_.flatten())
plt.xlabel('Вес признака')
plt.ylabel('Признак')
# Out:
# Text(0, 0.5, 'Признак')

# %% [markdown]
# #### Случайный лес

# %%
rf_model = RandomForestRegressor()
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_train_preds = rf_model.predict(x_train)
evaluate_preds(y_train, y_train_preds)
# Out:
# R2:	0.948
# MAE:	11896.069
# MSE:	444647319.373

# %%
y_test_preds = rf_model.predict(x_test)
evaluate_preds(y_test, y_test_preds)
# Out:
# R2:	0.705
# MAE:	30455.764
# MSE:	2602457113.263
